# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
from sqlalchemy import create_engine

# %%
#Read csv file
dataset='youtube_dataset.csv'
df=pd.read_csv(dataset,encoding="ISO-8859-1")

# %%
# Show first rows
df.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0   1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1   1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2   1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3   1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4   1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
#
#            userID                                        userID-href  \
# 0       PewDiePie        https://socialblade.com/youtube/c/pewdiepie
# 1        T-Series     https://socialblade.com/youtube/c/tseriesmusic
# 2          Gaming  https://socialblade.com/youtube/channel/UCOpNc...
# 3  YouTube Movies  https://socialblade.com/youtube/channel/UClgRk...
# 4          Sports  https://socialblade.com/youtube/channel/UCEgdi...
#
#              name  uploads  subscribers   videoviews country    channeltype  \
# ...

# %%
#selects rows (and columns) by position:
df1 = df.iloc [0:1001,:]
df1
# Out:
#      web-scraper-order                              web-scraper-start-url  \
# 0      1553043067-5148  https://socialblade.com/youtube/top/5000/mosts...
# 1      1553043063-5147  https://socialblade.com/youtube/top/5000/mosts...
# 2      1553043059-5146  https://socialblade.com/youtube/top/5000/mosts...
# 3      1553043055-5145  https://socialblade.com/youtube/top/5000/mosts...
# 4      1553043051-5144  https://socialblade.com/youtube/top/5000/mosts...
# ...                ...                                                ...
# 996    1553037792-3901  https://socialblade.com/youtube/top/5000/mosts...
# 997    1553037768-3897  https://socialblade.com/youtube/top/5000/mosts...
# 998    1553037724-3888  https://socialblade.com/youtube/top/5000/mosts...
# 999    1553037758-3896  https://socialblade.com/youtube/top/5000/mosts...
# 1000   1553037738-3892  https://socialblade.com/youtube/top/5000/mosts...
#
#                           userID  \
# 0                      PewDiePie
# ...

# %%
#Return object containing counts of Channeltype
df1['channeltype'].value_counts()
# Out:
# Entertainment    284
# Music            241
# Games            115
# Comedy            76
# People            72
# Howto             49
# Film              36
# Education         30
# Tech              19
# Sports            17
# News              17
# Autos              3
# Animals            2
# Nonprofit          1
# Travel             1
# Name: channeltype, dtype: int64

# %%
#Dataframe to csv file
df1.to_csv('youtube1000.csv')

# %%
#Create Engine
sqlEngine   = create_engine('mysql+pymysql://root:Ryan@123@localhost/assgn4')
dbConnection  = sqlEngine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16416/4071821931.py in <module>
#       1 #Create Engine
# ----> 2 sqlEngine   = create_engine('mysql+pymysql://root:Ryan@123@localhost/assgn4')
#       3 dbConnection  = sqlEngine.connect()
#
# <string> in create_engine(url, **kwargs)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\create.py in create_engine(url, **kwargs)
#     546             if k in kwargs:
#     547                 dbapi_args[k] = pop_kwarg(k)
# --> 548         dbapi = dialect_cls.dbapi(**dbapi_args)
#     549
# ...

# %%
#Write data to SQL
df1.to_sql('youtube1000', con=sqlEngine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16416/2380979074.py in <module>
#       1 #Write data to SQL
# ----> 2 df1.to_sql('youtube1000', con=sqlEngine)
#
# NameError: name 'sqlEngine' is not defined
